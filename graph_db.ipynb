# %%
import os
from pathlib import Path

from dotenv import load_dotenv


env_path = next(
    (path / ".env" for path in [Path.cwd(), *Path.cwd().parents] if (path / ".env").exists()),
    None,
)
if env_path is None:
    raise FileNotFoundError("Could not find a .env file in the workspace or its parent directories.")

load_dotenv(env_path)

NEO4J_URI = os.environ["NEO4J_URI"]
NEO4J_USERNAME = os.environ["NEO4J_USERNAME"]
NEO4J_PASSWORD = os.environ["NEO4J_PASSWORD"]
NEO4J_DATABASE = os.environ["NEO4J_DATABASE"]
GROQ_API_KEY = os.environ["GROQ_API_KEY"]

print(f"Loaded Neo4j configuration from {env_path}")
# Out:
# Loaded Neo4j configuration from /home/lakshay/graph_rag/.env

# %%
from langchain_community.graphs import Neo4jGraph

graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database=NEO4J_DATABASE,
)
# Out:
# /tmp/ipykernel_66117/1389125815.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.graphs import Neo4jGraph
# /tmp/ipykernel_66117/1389125815.py:3: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the `langchain-neo4j package and should be used instead. To use it run `pip install -U `langchain-neo4j` and import as `from `langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(

# %%
graph

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key=GROQ_API_KEY,
    model_name="openai/gpt-oss-20b",
    temperature=0,
    max_tokens=1000,
    reasoning_effort="low",
)

llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.4', 'langchain': '1.4.2'}}, profile={'name': 'GPT OSS 20B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x7fef801ce9f0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7fef801cf410>, model_name='openai/gpt-oss-20b', temperature=1e-08, reasoning_effort='low', model_kwargs={}, groq_api_key=SecretStr('**********'), max_tokens=1000)

# %%
from langchain_core.documents import Document 

text = """
Elon Reeve Musk (ⓘ EE-lon; born June 28, 1971) is a businessman and former public official who is the chief executive officer (CEO) and largest shareholder of Tesla and SpaceX. Musk has been the wealthiest person in the world since 2025, and briefly became the only trillionaire (in terms of US dollars) in June 2026; as of September 2026, Forbes estimates his net worth to be US$964 billion.

Born into the wealthy Musk family in Pretoria, South Africa, Musk emigrated in 1989 to Canada; he has Canadian citizenship since his mother was born there. He received bachelor's degrees in 1997 from the University of Pennsylvania before moving to California to pursue business ventures. In 1995, Musk co-founded Zip2, a web software company. Following its sale in 1999, he co-founded X.com, an e-commerce payment system that merged with Confinity in March 2000 to form PayPal, which was acquired by eBay in 2002. Musk also became an American citizen in 2002.

k family Elon Reeve Musk was born on June 28, 1971, in Pretoria, South Africa\'s administrative capital.[3][4] He is of British and Pennsylvania Dutch ancestry.[5][6] His mother, Maye (née Haldeman), is a model and dietitian born in Saskatchewan, Canada, and raised in South Africa.[7][8][9] Musk therefore holds both South African and Canadian citizenship from birth.[10] His father, Errol Musk, is a South African electromechanical engineer, pilot, sailor, consultant, emerald dealer, and property developer, who partly owned a rental lodge at ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100,
)
documents = text_splitter.create_documents([text])
print(f"Prepared {len(documents)} document chunks")
# Out:
# Prepared 12 document chunks

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer

llm_transformer = LLMGraphTransformer(
    llm=llm,
    allowed_nodes=["Person", "Organization", "Company", "Location"],
    ignore_tool_usage=True,
)

# %%
graph_documents = llm_transformer.convert_to_graph_documents(documents)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Tesla', type='Company', properties={}), Node(id='SpaceX', type='Company', properties={}), Node(id='Elon Reeve Musk', type='Person', properties={})], relationships=[Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Tesla', type='Company', properties={}), type='CEO_OF', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='SpaceX', type='Company', properties={}), type='CEO_OF', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Tesla', type='Company', properties={}), type='LARGEST_SHAREHOLDER_OF', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='SpaceX', type='Company', properties={}), type='LARGEST_SHAREHOLDER_OF', properties={})], source=Document(metadata={}, page_content='Elon Reeve Musk (ⓘ EE-lon; born June 28, 1971) is a businessman and former public official who is the chief executive officer (CEO) and largest shareholder of Tesla and SpaceX. Musk has been the wealthiest person in the world since 2025, and briefly became the only trillionaire (in terms of US dollars) in June 2026; as of September 2026, Forbes estimates his net worth to be US$964 billion.')),
#  GraphDocument(nodes=[Node(id='X.com', type='Company', properties={}), Node(id='eBay', type='Company', properties={}), Node(id='Musk', type='Person', properties={}), Node(id='University of Pennsylvania', type='Organization', properties={}), Node(id='Zip2', type='Company', properties={}), Node(id='Pretoria', type='Location', properties={}), Node(id='Confinity', type='Company', properties={}), Node(id='Canada', type='Location', properties={}), Node(id='PayPal', type='Company', properties={})], relationships=[Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='Pretoria', type='Location', properties={}), type='BORN_IN', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='Canada', type='Location', properties={}), type='EMIGRATED_TO', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='University of Pennsylvania', type='Organization', properties={}), type='RECEIVED_DEGREE_FROM', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='Zip2', type='Company', properties={}), type='CO_FOUND', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='X.com', type='Company', properties={}), type='CO_FOUND', properties={}), Relationship(source=Node(id='X.com', type='Company', properties={}), target=Node(id='Confinity', type='Company', properties={}), type='MERGED_WITH', properties={}), Relationship(source=Node(id='X.com', type='Company', properties={}), target=Node(id='Confinity', type='Company', properties={}), type='MERGED_WITH', properties={}), Relationship(source=Node(id='X.com', type='Company', properties={}), target=Node(id='PayPal', type='Company', properties={}), type='FORMED', properties={}), Relationship(source=Node(id='PayPal', type='Company', properties={}), target=Node(id='eBay', type='Company', properties={}), type='ACQUIRED_BY', properties={})], source=Document(metadata={}, page_content="Born into the wealthy Musk family in Pretoria, South Africa, Musk emigrated in 1989 to Canada; he has Canadian citizenship since his mother was born there. He received bachelor's degrees in 1997 from the University of Pennsylvania before moving to California to pursue business ventures. In 1995, Musk co-founded Zip2, a web software company. Following its sale in 1999, he co-founded X.com, an e-commerce payment system that merged with Confinity in March 2000 to form PayPal, which was acquired by eBay in 2002. Musk also became an American citizen in 2002.")),
#  GraphDocument(nodes=[Node(id='SpaceX', type='Company', properties={}), Node(id='Elon Musk', type='Person', properties={}), Node(id='X', type='Company', properties={}), Node(id='xAI', type='Company', properties={}), Node(id='OpenAI', type='Company', properties={}), Node(id='Twitter', type='Company', properties={}), Node(id='Tesla', type='Company', properties={}), Node(id='Neuralink', type='Company', properties={})], relationships=[Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='SpaceX', type='Company', properties={}), type='WORKS_FOR', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Tesla', type='Company', properties={}), type='WORKS_FOR', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Tesla', type='Company', properties={}), type='INVESTED_IN', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='OpenAI', type='Company', properties={}), type='WORKS_FOR', properties={}), Relationship(source=Node(id='xAI', type='Company', properties={}), target=Node(id='SpaceX', type='Company', properties={}), type='SUBSIDIARY_OF', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Twitter', type='Company', properties={}), type='ACQUIRED', properties={}), Relationship(source=Node(id='Twitter', type='Company', properties={}), target=Node(id='X', type='Company', properties={}), type='REBRANDED_TO', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Neuralink', type='Company', properties={}), type='OWNED_BY', properties={})], source=Document(metadata={}, page_content="In 2002, Musk founded and became CEO and chief engineer of SpaceX, a space technology company; the company has since led innovations in reusable rockets and commercial spaceflight. Musk joined Tesla as an early investor in 2004 and became its CEO and product architect in 2008; it has since become a leader in electric vehicles. In 2015, Musk co-founded OpenAI to advance artificial intelligence (AI) research, but later left; his growing discontent with the organization's direction and leadership in the AI boom in the 2020s led him to establish xAI, which became a subsidiary of SpaceX in 2026. In 2022, he acquired Twitter, a social networking service, and made significant changes, including rebranding it as X in 2023. His other businesses include Neuralink, a neurotechnology company that he")),
#  GraphDocument(nodes=[Node(id='Tesla', type='Company', properties={}), Node(id='Musk', type='Person', properties={}), Node(id='Boring Company', type='Company', properties={}), Node(id='Neuralink', type='Company', properties={})], relationships=[Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='Neuralink', type='Company', properties={}), type='CO_FOUNDED', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='Boring Company', type='Company', properties={}), type='FOUND', properties={}), Relationship(source=Node(id='Tesla', type='Company', properties={}), target=Node(id='Musk', type='Person', properties={}), type='APPROVED_PAY_PACKAGE_FOR', properties={})], source=Document(metadata={}, page_content='it as X in 2023. His other businesses include Neuralink, a neurotechnology company that he co-founded in 2016, and the Boring Company, a tunneling company that he founded in 2017. In November 2025, Tesla approved a pay package worth $1 trillion for Musk, which he is to receive over 10 years if certain milestones are met, such as achieving a market capitalization of $8.5 trillion. Musk became the first US-dollar trillionaire upon the initial public offering of SpaceX in June 2026, though a SpaceX stock collapse brought him under the threshold by the next month.')),
#  GraphDocument(nodes=[Node(id='2024 U.S. presidential election', type='Location', properties={}), Node(id='Elon Musk', type='Person', properties={}), Node(id='January 2025', type='Location', properties={}), Node(id='Donald Trump', type='Person', properties={}), Node(id='Trump administration', type='Organization', properties={}), Node(id='global far-right politics', type='Organization', properties={}), Node(id='President', type='Person', properties={}), Node(id='Department of Government Efficiency (DOGE)', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='2024 U.S. presidential election', type='Location', properties={}), type='DONATED_TO', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Donald Trump', type='Person', properties={}), type='SUPPORTED', properties={}), Relationship(source=Node(id='Donald Trump', type='Person', properties={}), target=Node(id='January 2025', type='Location', properties={}), type='INCOGNIZED_IN', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='President', type='Person', properties={}), type='SENIOR_ADVISOR_TO', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Department of Government Efficiency (DOGE)', type='Organization', properties={}), type='HEAD_OF', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Trump administration', type='Organization', properties={}), type='LEFT', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Donald Trump', type='Person', properties={}), type='FEUD_WITH', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='global far-right politics', type='Organization', properties={}), type='SUPPORTS', properties={})], source=Document(metadata={}, page_content='Musk was the largest donor in the 2024 U.S. presidential election, where he supported Donald Trump. After Trump was inaugurated in January 2025, Musk was Senior Advisor to the President and the de facto head of the Department of Government Efficiency (DOGE). Musk left the Trump administration in May 2025 and returned to managing his companies; shortly thereafter he had a public feud with Trump. Musk is a supporter of global far-right politics, figures, and political parties. His political activities, statements and views have made him a polarizing figure. He has been criticized for making unscientific and misleading statements, including spreading COVID-19 misinformation, promoting conspiracy theories, and affirming antisemitic, white nationalist, racist, and transphobic comments. His')),
#  GraphDocument(nodes=[Node(id='Trump administration', type='Organization', properties={}), Node(id='USAID', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Trump administration', type='Organization', properties={}), target=Node(id='USAID', type='Organization', properties={}), type='HAS_CUTS_BY', properties={})], source=Document(metadata={}, page_content='theories, and affirming antisemitic, white nationalist, racist, and transphobic comments. His acquisition of Twitter was controversial because, following his pledge to decrease censorship, there was an increase in hate speech and misinformation on the service. His role in the second Trump administration attracted public backlash, particularly in response to DOGE and its cuts to the US Agency for International Development (USAID).')),
#  GraphDocument(nodes=[Node(id='British', type='Person', properties={}), Node(id='Errol Musk', type='Person', properties={}), Node(id='Timbavati Private Nature Reserve', type='Location', properties={}), Node(id='Pennsylvania Dutch', type='Person', properties={}), Node(id='South African', type='Location', properties={}), Node(id='Maye Haldeman', type='Person', properties={}), Node(id='Canadian', type='Location', properties={}), Node(id='South Africa', type='Location', properties={}), Node(id='Pretoria', type='Location', properties={}), Node(id='Elon Reeve Musk', type='Person', properties={}), Node(id='Saskatchewan', type='Location', properties={})], relationships=[Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Pretoria', type='Location', properties={}), type='BORN_IN', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='British', type='Person', properties={}), type='HAS_ANCESTRY', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Pennsylvania Dutch', type='Person', properties={}), type='HAS_ANCESTRY', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='South African', type='Location', properties={}), type='HAS_CITIZENSHIP', properties={}), Relationship(source=Node(id='Elon Reeve Musk', type='Person', properties={}), target=Node(id='Canadian', type='Location', properties={}), type='HAS_CITIZENSHIP', properties={}), Relationship(source=Node(id='Maye Haldeman', type='Person', properties={}), target=Node(id='Elon Reeve Musk', type='Person', properties={}), type='MOTHER_OF', properties={}), Relationship(source=Node(id='Maye Haldeman', type='Person', properties={}), target=Node(id='Saskatchewan', type='Location', properties={}), type='BORN_IN', properties={}), Relationship(source=Node(id='Maye Haldeman', type='Person', properties={}), target=Node(id='South Africa', type='Location', properties={}), type='RAN_IN', properties={}), Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Elon Reeve Musk', type='Person', properties={}), type='FATHER_OF', properties={}), Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Timbavati Private Nature Reserve', type='Location', properties={}), type='OWNED_PARTLY', properties={})], source=Document(metadata={}, page_content="Early life and education See also: Musk family Elon Reeve Musk was born on June 28, 1971, in Pretoria, South Africa's administrative capital.[3][4] He is of British and Pennsylvania Dutch ancestry.[5][6] His mother, Maye (née Haldeman), is a model and dietitian born in Saskatchewan, Canada, and raised in South Africa.[7][8][9] Musk therefore holds both South African and Canadian citizenship from birth.[10] His father, Errol Musk, is a South African electromechanical engineer, pilot, sailor, consultant, emerald dealer, and property developer, who partly owned a rental lodge at Timbavati Private Nature Reserve.[11][12][13][14]")),
#  GraphDocument(nodes=[Node(id='political activist', type='Person', properties={}), Node(id='South Africa', type='Location', properties={}), Node(id='Elon Musk', type='Person', properties={}), Node(id='aviator', type='Person', properties={}), Node(id='chiropractor', type='Person', properties={}), Node(id='American-born Canadian', type='Person', properties={}), Node(id='Joshua N. Haldeman', type='Person', properties={})], relationships=[Relationship(source=Node(id='Joshua N. Haldeman', type='Person', properties={}), target=Node(id='chiropractor', type='Person', properties={}), type='HAS_ROLE', properties={}), Relationship(source=Node(id='Joshua N. Haldeman', type='Person', properties={}), target=Node(id='aviator', type='Person', properties={}), type='HAS_ROLE', properties={}), Relationship(source=Node(id='Joshua N. Haldeman', type='Person', properties={}), target=Node(id='political activist', type='Person', properties={}), type='HAS_ROLE', properties={}), Relationship(source=Node(id='Joshua N. Haldeman', type='Person', properties={}), target=Node(id='South Africa', type='Location', properties={}), type='MOVED_TO', properties={}), Relationship(source=Node(id='Joshua N. Haldeman', type='Person', properties={}), target=Node(id='American-born Canadian', type='Person', properties={}), type='HAS_NATIONALITY', properties={}), Relationship(source=Node(id='Joshua N. Haldeman', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='INFLUENCED', properties={})], source=Document(metadata={}, page_content='His maternal grandfather, Joshua N. Haldeman, who died in a plane crash when Musk was a toddler, was an American-born Canadian chiropractor, aviator and political activist in the technocracy movement[15][16] who moved to South Africa in 1950.[17] Haldeman\'s anti-government, anti-democratic and conspiracist views, which included the promotion of far-right antisemitic conspiracy theories,[18][19] "fanatical" support of apartheid,[19] and according to Errol, support of Nazism,[17] have been suggested as an influence on Musk.[20][21][22][23] During his childhood, Musk was told stories by his grandmother of Haldeman\'s travels and exploits, and he has suggested that all of Haldeman\'s descendants have his "desire for adventure, exploration – doing crazy things".[24]')),
#  GraphDocument(nodes=[Node(id='Progressive Party', type='Organization', properties={}), Node(id='Kimbal Musk', type='Person', properties={}), Node(id='Elon Musk', type='Person', properties={}), Node(id='Zambian emerald mine', type='Organization', properties={}), Node(id='Errol Musk', type='Person', properties={}), Node(id='Paternal half-siblings', type='Person', properties={}), Node(id='Pretoria City Council', type='Organization', properties={}), Node(id='Tosca Musk', type='Person', properties={}), Node(id='Anglican Church of Southern Africa', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Kimbal Musk', type='Person', properties={}), type='HAS_SIBLING', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Tosca Musk', type='Person', properties={}), type='HAS_SIBLING', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Paternal half-siblings', type='Person', properties={}), type='HAS_HALF_SIBLING', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Anglican Church of Southern Africa', type='Organization', properties={}), type='BAPTIZED_IN', properties={}), Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Zambian emerald mine', type='Organization', properties={}), type='PART_OWNER_OF', properties={}), Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Pretoria City Council', type='Organization', properties={}), type='ELECTED_TO', properties={}), Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Progressive Party', type='Organization', properties={}), type='REPRESENTS', properties={})], source=Document(metadata={}, page_content='Musk has a younger brother, Kimbal, a younger sister, Tosca, and four paternal half-siblings.[25][26][9][27] He was baptized as a child in the Anglican Church of Southern Africa.[28][29] The Musk family was wealthy during his youth.[14] Despite both Musk and Errol previously stating that Errol was a part owner of a Zambian emerald mine,[14] in 2023, Errol recounted that the deal he made was to receive "a portion of the emeralds produced at three small mines".[30][31] Errol was elected to the Pretoria City Council as a representative of the anti-apartheid Progressive Party and has said that his children shared their father\'s dislike of apartheid.[3]')),
#  GraphDocument(nodes=[Node(id='Musk', type='Person', properties={}), Node(id='Errol', type='Person', properties={}), Node(id='father', type='Person', properties={}), Node(id='concrete steps', type='Location', properties={})], relationships=[Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='concrete steps', type='Location', properties={}), type='THROWN_DOWN', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='Musk', type='Person', properties={}), type='BEATEN_SEVERELY', properties={}), Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='father', type='Person', properties={}), type='BERATED_BY', properties={})], source=Document(metadata={}, page_content='After his parents divorced in 1979, Musk, aged around 9, chose to live with his father because he had an Encyclopædia Britannica set and a computer.[32][5][11] He later regretted his decision and became estranged from his father.[33] Musk has recounted trips to a wilderness school that he described as a "paramilitary Lord of the Flies" where "bullying was a virtue" and children were encouraged to fight over rations.[34] In one incident, after an altercation with a fellow pupil, Musk was thrown down concrete steps and beaten severely, leading to him being hospitalized for his injuries.[35] He described his father berating him after he was discharged from the hospital.[35] Errol denied berating Musk and claimed, "The [other] boy had just lost his father to suicide, and Musk had called him')),
#  GraphDocument(nodes=[], relationships=[], source=Document(metadata={}, page_content='Musk and claimed, "The [other] boy had just lost his father to suicide, and Musk had called him stupid. He had a tendency to call people stupid. How could I possibly blame that child?"[36]')),
#  GraphDocument(nodes=[Node(id='Musk', type='Person', properties={}), Node(id='PC and Office Technology magazine', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Musk', type='Person', properties={}), target=Node(id='PC and Office Technology magazine', type='Organization', properties={}), type='SOLD_TO', properties={})], source=Document(metadata={}, page_content="Musk was an enthusiastic reader of books, and had attributed his success in part to having read The Lord of the Rings, the Foundation series, and The Hitchhiker's Guide to the Galaxy.[13][37] At age ten, he developed an interest in computing and video games, teaching himself how to program from the VIC-20 user manual.[38] At age twelve, in 1983, Musk sold his BASIC-based game Blastar to PC and Office Technology magazine for approximately $500 (equivalent to $1,600 in 2025).[39][40]"))]
